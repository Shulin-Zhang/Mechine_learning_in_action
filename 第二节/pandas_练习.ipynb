# %%
import pandas as pd
from matplotlib import pylab as plt

# %matplotlib inline

# %%
df = pd.read_csv('titanic.csv')
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ### 删除行列

# %%
df.drop([1, 2]).head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                       Braund, Mr. Owen Harris    male  22.0      1      0
# 3  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
# 4                      Allen, Mr. William Henry    male  35.0      0      0
# 5                              Moran, Mr. James    male   NaN      0      0
# 6                       McCarthy, Mr. Timothy J    male  54.0      0      0
#
#       Ticket     Fare Cabin Embarked
# 0  A/5 21171   7.2500   NaN        S
# 3     113803  53.1000  C123        S
# 4     373450   8.0500   NaN        S
# 5     330877   8.4583   NaN        Q
# 6      17463  51.8625   E46        S

# %%
df.drop(['Cabin', 'Fare'], axis=1).head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket Embarked
# 0      0         A/5 21171        S
# 1      0          PC 17599        C
# 2      0  STON/O2. 3101282        S
# 3      0            113803        S
# 4      0            373450        S

# %% [markdown]
# ### 插入列

# %%
df.insert(1, 'Test', 1)

# %%
df.head()
# Out:
#    PassengerId  Test  Survived  Pclass  \
# 0            1     1         0       3
# 1            2     1         1       1
# 2            3     1         1       3
# 3            4     1         1       1
# 4            5     1         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# ...

# %% [markdown]
# ### 均值 方差

# %%
df.mean()
# Out:
# PassengerId    446.000000
# Test             1.000000
# Survived         0.383838
# Pclass           2.308642
# Age             29.699118
# SibSp            0.523008
# Parch            0.381594
# Fare            32.204208
# dtype: float64

# %%
df.std()
# Out:
# PassengerId    257.353842
# Test             0.000000
# Survived         0.486592
# Pclass           0.836071
# Age             14.526497
# SibSp            1.102743
# Parch            0.806057
# Fare            49.693429
# dtype: float64

# %%
df.Age.mean()
# Out:
# 29.69911764705882

# %% [markdown]
# ### 画图

# %%
df.hist(column='Pclass')
plt.title('pclass')
# Out:
# Text(0.5,1,'pclass')

# %% [markdown]
# ### 取个样本

# %%
df.sample(10)
# Out:
#      PassengerId  Test  Survived  Pclass  \
# 705          706     1         0       2
# 69            70     1         0       3
# 287          288     1         0       3
# 376          377     1         1       3
# 582          583     1         0       2
# 807          808     1         0       3
# 708          709     1         1       1
# 661          662     1         0       3
# 593          594     1         0       3
# 46            47     1         0       3
#
#                                                Name     Sex   Age  SibSp  \
# 705  Morley, Mr. Henry Samuel ("Mr Henry Marshall")    male  39.0      0
# 69                                Kink, Mr. Vincenz    male  26.0      2
# 287                            Naidenoff, Mr. Penko    male  22.0      0
# 376                 Landergren, Miss. Aurora Adelia  female  22.0      0
# 582                      Downton, Mr. William James    male  54.0      0
# ...

# %%
df.rename(columns={'Test': 'ABC'}, inplace=True)
df.head()
# Out:
#    PassengerId  ABC  Survived  Pclass  \
# 0            1    1         0       3
# 1            2    1         1       1
# 2            3    1         1       3
# 3            4    1         1       1
# 4            5    1         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# ...
